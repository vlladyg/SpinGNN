# %% [markdown]
# ### First few cells is just data preparation

# %% [markdown]
# My implementation is build on top of nequip and allegro python libraries to simplify data load and preprocessing.
# The wigner simbols are from e3nn
# Here are the links
# https://github.com/mir-group/nequip
# https://github.com/mir-group/allegro

# %%
# reference example
from nequip.data import dataset_from_config
from nequip.utils import Config
#from nequip.utils.misc import get_default_device_name
#from nequip.utils.config import _GLOBAL_ALL_ASKED_FOR_KEYS

from nequip.model import model_from_config


default_config = dict(
    root="./",
    tensorboard=False,
    wandb=False,
    model_builders=[
        "SimpleIrrepsConfig",
        "EnergyModel",
        "PerSpeciesRescale",
        "StressForceOutput",
        "RescaleEnergyEtc",
    ],
    dataset_statistics_stride=1,
    device='cuda:0',
    default_dtype="float64",
    model_dtype="float32",
    allow_tf32=True,
    verbose="INFO",
    model_debug_mode=False,
    equivariance_test=False,
    grad_anomaly_mode=False,
    gpu_oom_offload=False,
    append=False,
    warn_unused=False,
    _jit_bailout_depth=2,  # avoid 20 iters of pain, see https://github.com/pytorch/pytorch/issues/52286
    # Quote from eelison in PyTorch slack:
    # https://pytorch.slack.com/archives/CDZD1FANA/p1644259272007529?thread_ts=1644064449.039479&cid=CDZD1FANA
    # > Right now the default behavior is to specialize twice on static shapes and then on dynamic shapes.
    # > To reduce warmup time you can do something like setFusionStrartegy({{FusionBehavior::DYNAMIC, 3}})
    # > ... Although we would wouldn't really expect to recompile a dynamic shape fusion in a model,
    # > provided broadcasting patterns remain fixed
    # We default to DYNAMIC alone because the number of edges is always dynamic,
    # even if the number of atoms is fixed:
    _jit_fusion_strategy=[("DYNAMIC", 3)],
    # Due to what appear to be ongoing bugs with nvFuser, we default to NNC (fuser1) for now:
    # TODO: still default to NNC on CPU regardless even if change this for GPU
    # TODO: default for ROCm?
    _jit_fuser="fuser1",
)

# All default_config keys are valid / requested
#_GLOBAL_ALL_ASKED_FOR_KEYS.update(default_config.keys())

# %%
config = Config.from_file('./config/example_ETN_opt_MEA.yaml', defaults=default_config)
    

dataset = dataset_from_config(config, prefix="dataset")

validation_dataset = None

dataset[0]
# Out:
# Processing dataset...
# [W130 20:58:15.781158407 init.cpp:809] Warning: nvfuser is no longer supported in torch script, use _jit_nvfuser_enabled is deprecated and a no-op (function operator())
# [W130 20:58:15.781189892 init.cpp:767] Warning: nvfuser is no longer supported in torch script, use _jit_set_nvfuser_enabled is deprecated and a no-op (function operator())
# [W130 20:58:15.781197073 init.cpp:767] Warning: nvfuser is no longer supported in torch script, use _jit_set_nvfuser_enabled is deprecated and a no-op (function operator())
# [W130 20:58:15.082626942 init.cpp:809] Warning: nvfuser is no longer supported in torch script, use _jit_nvfuser_enabled is deprecated and a no-op (function operator())
# [W130 20:58:15.084201618 init.cpp:767] Warning: nvfuser is no longer supported in torch script, use _jit_set_nvfuser_enabled is deprecated and a no-op (function operator())
# [W130 20:58:15.084339506 init.cpp:767] Warning: nvfuser is no longer supported in torch script, use _jit_set_nvfuser_enabled is deprecated and a no-op (function operator())
# [W130 20:58:15.157594858 init.cpp:809] Warning: nvfuser is no longer supported in torch script, use _jit_nvfuser_enabled is deprecated and a no-op (function operator())
# [W130 20:58:15.157683318 init.cpp:767] Warning: nvfuser is no longer supported in torch script, use _jit_set_nvfuser_enabled is deprecated and a no-op (function operator())
# [W130 20:58:15.157711750 init.cpp:767] Warning: nvfuser is no longer supported in torch script, use _jit_set_nvfuser_enabled is deprecated and a no-op (function operator())
# [W130 20:58:15.173006242 init.cpp:809] Warning: nvfuser is no longer supported in torch script, use _jit_nvfuser_enabled is deprecated and a no-op (function operator())
# [W130 20:58:15.173121135 init.cpp:767] Warning: nvfuser is no longer supported in torch script, use _jit_set_nvfuser_enabled is deprecated and a no-op (function operator())
# [W130 20:58:15.173151268 init.cpp:767] Warning: nvfuser is no longer supported in torch script, use _jit_set_nvfuser_enabled is deprecated and a no-op (function operator())
# [W130 20:58:15.257607611 init.cpp:809] Warning: nvfuser is no longer supported in torch script, use _jit_nvfuser_enabled is deprecated and a no-op (function operator())
# [W130 20:58:15.257740186 init.cpp:767] Warning: nvfuser is no longer supported in torch script, use _jit_set_nvfuser_enabled is deprecated and a no-op (function operator())
# [W130 20:58:15.257773004 init.cpp:767] Warning: nvfuser is no longer supported in torch script, use _jit_set_nvfuser_enabled is deprecated and a no-op (function operator())
# [W130 20:58:15.260341276 init.cpp:809] Warning: nvfuser is no longer supported in torch script, use _jit_nvfuser_enabled is deprecated and a no-op (function operator())
# [W130 20:58:15.260429557 init.cpp:767] Warning: nvfuser is no longer supported in torch script, use _jit_set_nvfuser_enabled is deprecated and a no-op (function operator())
# [W130 20:58:15.260454072 init.cpp:767] Warning: nvfuser is no longer supported in torch script, use _jit_set_nvfuser_enabled is deprecated and a no-op (function operator())
# [W130 20:58:16.305630586 init.cpp:809] Warning: nvfuser is no longer supported in torch script, use _jit_nvfuser_enabled is deprecated and a no-op (function operator())
# [W130 20:58:16.305656545 init.cpp:767] Warning: nvfuser is no longer supported in torch script, use _jit_set_nvfuser_enabled is deprecated and a no-op (function operator())
# [W130 20:58:16.305663153 init.cpp:767] Warning: nvfuser is no longer supported in torch script, use _jit_set_nvfuser_enabled is deprecated and a no-op (function operator())
# [W130 20:58:16.314832842 init.cpp:809] Warning: nvfuser is no longer supported in torch script, use _jit_nvfuser_enabled is deprecated and a no-op (function operator())
# [W130 20:58:16.314956440 init.cpp:767] Warning: nvfuser is no longer supported in torch script, use _jit_set_nvfuser_enabled is deprecated and a no-op (function operator())
# [W130 20:58:16.314978828 init.cpp:767] Warning: nvfuser is no longer supported in torch script, use _jit_set_nvfuser_enabled is deprecated and a no-op (function operator())
# [W130 20:58:16.326074010 init.cpp:809] Warning: nvfuser is no longer supported in torch script, use _jit_nvfuser_enabled is deprecated and a no-op (function operator())
# [W130 20:58:16.326208974 init.cpp:767] Warning: nvfuser is no longer supported in torch script, use _jit_set_nvfuser_enabled is deprecated and a no-op (function operator())
# [W130 20:58:16.326238940 init.cpp:767] Warning: nvfuser is no longer supported in torch script, use _jit_set_nvfuser_enabled is deprecated and a no-op (function operator())
# [W130 20:58:16.332005241 init.cpp:809] Warning: nvfuser is no longer supported in torch script, use _jit_nvfuser_enabled is deprecated and a no-op (function operator())
# [W130 20:58:16.332112633 init.cpp:767] Warning: nvfuser is no longer supported in torch script, use _jit_set_nvfuser_enabled is deprecated and a no-op (function operator())
# [W130 20:58:16.332145661 init.cpp:767] Warning: nvfuser is no longer supported in torch script, use _jit_set_nvfuser_enabled is deprecated and a no-op (function operator())
# [W130 20:58:16.348535462 init.cpp:809] Warning: nvfuser is no longer supported in torch script, use _jit_nvfuser_enabled is deprecated and a no-op (function operator())
# [W130 20:58:16.348659582 init.cpp:767] Warning: nvfuser is no longer supported in torch script, use _jit_set_nvfuser_enabled is deprecated and a no-op (function operator())
# [W130 20:58:16.348688848 init.cpp:767] Warning: nvfuser is no longer supported in torch script, use _jit_set_nvfuser_enabled is deprecated and a no-op (function operator())
# [W130 20:58:16.381393399 init.cpp:809] Warning: nvfuser is no longer supported in torch script, use _jit_nvfuser_enabled is deprecated and a no-op (function operator())
# [W130 20:58:16.381529689 init.cpp:767] Warning: nvfuser is no longer supported in torch script, use _jit_set_nvfuser_enabled is deprecated and a no-op (function operator())
# [W130 20:58:16.381560461 init.cpp:767] Warning: nvfuser is no longer supported in torch script, use _jit_set_nvfuser_enabled is deprecated and a no-op (function operator())
# [W130 20:58:16.382187826 init.cpp:809] Warning: nvfuser is no longer supported in torch script, use _jit_nvfuser_enabled is deprecated and a no-op (function operator())
# [W130 20:58:16.382282739 init.cpp:767] Warning: nvfuser is no longer supported in torch script, use _jit_set_nvfuser_enabled is deprecated and a no-op (function operator())
# [W130 20:58:16.382320773 init.cpp:767] Warning: nvfuser is no longer supported in torch script, use _jit_set_nvfuser_enabled is deprecated and a no-op (function operator())
# [W130 20:58:16.397493983 init.cpp:809] Warning: nvfuser is no longer supported in torch script, use _jit_nvfuser_enabled is deprecated and a no-op (function operator())
# [W130 20:58:16.397575524 init.cpp:767] Warning: nvfuser is no longer supported in torch script, use _jit_set_nvfuser_enabled is deprecated and a no-op (function operator())
# [W130 20:58:16.397605357 init.cpp:767] Warning: nvfuser is no longer supported in torch script, use _jit_set_nvfuser_enabled is deprecated and a no-op (function operator())
# [W130 20:58:16.501468014 init.cpp:809] Warning: nvfuser is no longer supported in torch script, use _jit_nvfuser_enabled is deprecated and a no-op (function operator())
# [W130 20:58:16.501602707 init.cpp:767] Warning: nvfuser is no longer supported in torch script, use _jit_set_nvfuser_enabled is deprecated and a no-op (function operator())
# [W130 20:58:16.501646805 init.cpp:767] Warning: nvfuser is no longer supported in torch script, use _jit_set_nvfuser_enabled is deprecated and a no-op (function operator())
# [W130 20:58:16.538206678 init.cpp:809] Warning: nvfuser is no longer supported in torch script, use _jit_nvfuser_enabled is deprecated and a no-op (function operator())
# [W130 20:58:16.538233899 init.cpp:767] Warning: nvfuser is no longer supported in torch script, use _jit_set_nvfuser_enabled is deprecated and a no-op (function operator())
# [W130 20:58:16.538243030 init.cpp:767] Warning: nvfuser is no longer supported in torch script, use _jit_set_nvfuser_enabled is deprecated and a no-op (function operator())
# [W130 20:58:16.551030548 init.cpp:809] Warning: nvfuser is no longer supported in torch script, use _jit_nvfuser_enabled is deprecated and a no-op (function operator())
# [W130 20:58:16.551136991 init.cpp:767] Warning: nvfuser is no longer supported in torch script, use _jit_set_nvfuser_enabled is deprecated and a no-op (function operator())
# [W130 20:58:16.551169514 init.cpp:767] Warning: nvfuser is no longer supported in torch script, use _jit_set_nvfuser_enabled is deprecated and a no-op (function operator())
# [W130 20:58:16.558013210 init.cpp:809] Warning: nvfuser is no longer supported in torch script, use _jit_nvfuser_enabled is deprecated and a no-op (function operator())
# [W130 20:58:16.558091354 init.cpp:767] Warning: nvfuser is no longer supported in torch script, use _jit_set_nvfuser_enabled is deprecated and a no-op (function operator())
# [W130 20:58:16.558120742 init.cpp:767] Warning: nvfuser is no longer supported in torch script, use _jit_set_nvfuser_enabled is deprecated and a no-op (function operator())
# [W130 20:58:16.572472913 init.cpp:809] Warning: nvfuser is no longer supported in torch script, use _jit_nvfuser_enabled is deprecated and a no-op (function operator())
# [W130 20:58:16.572547596 init.cpp:767] Warning: nvfuser is no longer supported in torch script, use _jit_set_nvfuser_enabled is deprecated and a no-op (function operator())
# [W130 20:58:16.572568172 init.cpp:767] Warning: nvfuser is no longer supported in torch script, use _jit_set_nvfuser_enabled is deprecated and a no-op (function operator())
# [W130 20:58:16.654719406 init.cpp:809] Warning: nvfuser is no longer supported in torch script, use _jit_nvfuser_enabled is deprecated and a no-op (function operator())
# [W130 20:58:16.654800671 init.cpp:767] Warning: nvfuser is no longer supported in torch script, use _jit_set_nvfuser_enabled is deprecated and a no-op (function operator())
# [W130 20:58:16.654829602 init.cpp:767] Warning: nvfuser is no longer supported in torch script, use _jit_set_nvfuser_enabled is deprecated and a no-op (function operator())
# [W130 20:58:16.692033429 init.cpp:809] Warning: nvfuser is no longer supported in torch script, use _jit_nvfuser_enabled is deprecated and a no-op (function operator())
# [W130 20:58:16.692063333 init.cpp:767] Warning: nvfuser is no longer supported in torch script, use _jit_set_nvfuser_enabled is deprecated and a no-op (function operator())
# [W130 20:58:16.692072327 init.cpp:767] Warning: nvfuser is no longer supported in torch script, use _jit_set_nvfuser_enabled is deprecated and a no-op (function operator())
# [W130 20:58:16.726730546 init.cpp:809] Warning: nvfuser is no longer supported in torch script, use _jit_nvfuser_enabled is deprecated and a no-op (function operator())
# [W130 20:58:16.727982601 init.cpp:767] Warning: nvfuser is no longer supported in torch script, use _jit_set_nvfuser_enabled is deprecated and a no-op (function operator())
# [W130 20:58:16.728089663 init.cpp:767] Warning: nvfuser is no longer supported in torch script, use _jit_set_nvfuser_enabled is deprecated and a no-op (function operator())
# [W130 20:58:16.791773153 init.cpp:809] Warning: nvfuser is no longer supported in torch script, use _jit_nvfuser_enabled is deprecated and a no-op (function operator())
# [W130 20:58:16.792078090 init.cpp:767] Warning: nvfuser is no longer supported in torch script, use _jit_set_nvfuser_enabled is deprecated and a no-op (function operator())
# [W130 20:58:16.792121443 init.cpp:767] Warning: nvfuser is no longer supported in torch script, use _jit_set_nvfuser_enabled is deprecated and a no-op (function operator())
# [W130 20:58:16.883470543 init.cpp:809] Warning: nvfuser is no longer supported in torch script, use _jit_nvfuser_enabled is deprecated and a no-op (function operator())
# [W130 20:58:16.883586777 init.cpp:767] Warning: nvfuser is no longer supported in torch script, use _jit_set_nvfuser_enabled is deprecated and a no-op (function operator())
# [W130 20:58:16.883637249 init.cpp:767] Warning: nvfuser is no longer supported in torch script, use _jit_set_nvfuser_enabled is deprecated and a no-op (function operator())
# /home/vladimir/anaconda3/envs/spingnn/lib/python3.10/site-packages/nequip/data/_dataset/_ase_dataset.py:229: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   datas = [torch.load(d) for d in datas]
# Done!
# AtomicData(atom_types=[2, 1], cell=[3, 3], edge_cell_shift=[52, 3], edge_index=[2, 52], forces=[2, 3], pbc=[3], pos=[2, 3], stress=[3, 3], total_energy=[1])

# %%
# Trainer
from nequip.train.trainer import Trainer
from e3nn import o3

trainer = Trainer(model=None, **Config.as_dict(config))

# what is this
# to update wandb data?
config.update(trainer.params)

# = Train/test split =
trainer.set_dataset(dataset, validation_dataset)

# Some hyperparameteres
Nc = 3 # number of chennels for F features from ETN paper
N_rank_spec = 2 # hidden rank of reduction for type radial tensor
config['Nc'] = Nc
config['N_rank_spec'] = N_rank_spec

# ETN parameters
config['d'] = 3 # dimention of the tensor train
config['N_rank_ett'] = [2] # ranks of tensor train



# = Build model =
final_model = model_from_config(
    config=config, initialize=True, dataset=trainer.dataset_train
)
# Out:
# DEBUG:root:* Initialize Output
#   ...generate file name results/MEA/example/log
#   ...open log file results/MEA/example/log
#   ...generate file name results/MEA/example/metrics_epoch.csv
#   ...open log file results/MEA/example/metrics_epoch.csv
#   ...generate file name results/MEA/example/metrics_initialization.csv
#   ...open log file results/MEA/example/metrics_initialization.csv
#   ...generate file name results/MEA/example/metrics_batch_train.csv
#   ...open log file results/MEA/example/metrics_batch_train.csv
#   ...generate file name results/MEA/example/metrics_batch_val.csv
#   ...open log file results/MEA/example/metrics_batch_val.csv
#   ...generate file name results/MEA/example/best_model.pth
#   ...generate file name results/MEA/example/last_model.pth
#   ...generate file name results/MEA/example/trainer.pth
#   ...generate file name results/MEA/example/config.yaml
# Torch device: cuda:0
# instantiate Loss
# ...Loss_param = dict(
# ...   optional_args = {'coeff_schedule': 'constant'},
# ...   positional_args = {'coeffs': {'forces': 1.0, 'total_energy': [1.0, 'PerAtomMSELoss']}})
# instantiate MSELoss
# ...MSELoss_param = dict(
# ...   optional_args = {'size_average': None, 'reduce': None},
# ...   positional_args = {'reduction': 'none'})
#  parsing forces 1.0
#  parsing 1.0 MSELoss
# instantiate MSELoss
# ...MSELoss_param = dict(
# ...   optional_args = {'size_average': None, 'reduce': None},
# ...   positional_args = {'reduction': 'none'})
#  parsing total_energy [1.0, 'PerAtomMSELoss']
#  parsing 1.0 PerAtomMSELoss
# create loss instance <class 'nequip.train._loss.PerAtomLoss'>
# instantiate MSELoss
# ...MSELoss_param = dict(
# ...   optional_args = {'size_average': None, 'reduce': None},
# ...   positional_args = {'reduction': 'none'})
# Building ETN model...
# instantiate PairTypeEmbedding
#         all_args :                                           num_types
# ...PairTypeEmbedding_param = dict(
# ...   optional_args = {'num_types': 4},
# ...   positional_args = {'irreps_in': None})
# instantiate OneHotAtomEncoding
#         all_args :                                           num_types
# ...OneHotAtomEncoding_param = dict(
# ...   optional_args = {'set_features': True, 'num_types': 4},
# ...   positional_args = {'irreps_in': {'pos': 1x1oe, 'edge_index': None, 'edge_types': 1x0ee}})
# instantiate RadialBasisEdgeEncoding
#         all_args :                                  basis_kwargs.r_max <-                                              r_max
#         all_args :            basis_kwargs.original_basis_kwargs.r_max <-                                              r_max
#         all_args :        basis_kwargs.original_basis_kwargs.trainable <-                              BesselBasis_trainable
#         all_args :                                 cutoff_kwargs.r_max <-                                              r_max
#         all_args :                                     cutoff_kwargs.p <-                                 PolynomialCutoff_p
#    optional_args :                                               basis
#    optional_args :                                           out_field
# ...RadialBasisEdgeEncoding_param = dict(
# ...   optional_args = {'basis': <class 'allegro.nn._norm_basis.NormalizedBasis'>, 'cutoff': <class 'nequip.nn.cutoffs.PolynomialCutoff'>, 'basis_kwargs': {'r_min': 0.0, 'original_basis': <class 'nequip.nn.radial_basis.BesselBasis'>, 'original_basis_kwargs': {'num_basis': 8, 'trainable': True, 'r_max': 5.0}, 'n': 4000, 'norm_basis_mean_shift': True, 'r_max': 5.0}, 'cutoff_kwargs': {'p': 6, 'r_max': 5.0}, 'out_field': 'edge_embedding'},
# ...   positional_args = {'irreps_in': {'pos': 1x1oe, 'edge_index': None, 'edge_types': 1x0ee, 'node_attrs': 4x0ee, 'node_features': 4x0ee}})
# instantiate SphericalHarmonicEdgeAttrs
#         all_args :                                      irreps_edge_sh
# ...SphericalHarmonicEdgeAttrs_param = dict(
# ...   optional_args = {'edge_sh_normalization': 'component', 'edge_sh_normalize': True, 'out_field': 'edge_attrs', 'irreps_edge_sh': '1x0ee+1x1oe+1x2ee'},
# ...   positional_args = {'irreps_in': {'pos': 1x1oe, 'edge_index': None, 'edge_types': 1x0ee, 'node_attrs': 4x0ee, 'node_features': 4x0ee, 'edge_embedding': 8x0ee, 'edge_cutoff': 1x0ee}})
# instantiate EdgeFeatures_F
#         all_args :                                           num_types
#    optional_args :                                                  Nc
#    optional_args :                                         N_rank_spec
#    optional_args :                                           out_field
# ...EdgeFeatures_F_param = dict(
# ...   optional_args = {'num_basis': 8, 'N_rank_spec': 2, 'out_field': 'edge_features_F', 'Nc': 3, 'num_types': 4},
# ...   positional_args = {'irreps_in': {'pos': 1x1oe, 'edge_index': None, 'edge_types': 1x0ee, 'node_attrs': 4x0ee, 'node_features': 4x0ee, 'edge_embedding': 8x0ee, 'edge_cutoff': 1x0ee, 'edge_attrs': 1x0ee+1x1oe+1x2ee}})
# instantiate EdgewiseFSum
#         all_args :                                   avg_num_neighbors
#         all_args :                                           num_types
# ...EdgewiseFSum_param = dict(
# ...   optional_args = {'avg_num_neighbors': 26.194469451904297, 'normalize_edge_features_f': True, 'per_edge_species_scale': False, 'num_types': 4},
# ...   positional_args = {'irreps_in': {'pos': 1x1oe, 'edge_index': None, 'edge_types': 1x0ee, 'node_attrs': 4x0ee, 'node_features': 4x0ee, 'edge_embedding': 8x0ee, 'edge_cutoff': 1x0ee, 'edge_attrs': 1x0ee+1x1oe+1x2ee, 'edge_features_F': 3x0ee+3x1oe+3x2ee}})
# instantiate ETN_Module_opt
#    optional_args :                                          N_rank_ett
#    optional_args :                                                   d
#    optional_args :                                           out_field
# ...ETN_Module_opt_param = dict(
# ...   optional_args = {'out_field': 'atomic_energy', 'd': 3, 'N_rank_ett': [2]},
# ...   positional_args = {'irreps_in': {'pos': 1x1oe, 'edge_index': None, 'edge_types': 1x0ee, 'node_attrs': 4x0ee, 'node_features': 4x0ee, 'edge_embedding': 8x0ee, 'edge_cutoff': 1x0ee, 'edge_attrs': 1x0ee+1x1oe+1x2ee, 'edge_features_F': 3x0ee+3x1oe+3x2ee, 'node_features_F': 3x0ee+3x1oe+3x2ee}})
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File ~/anaconda3/envs/spingnn/lib/python3.10/site-packages/nequip/utils/auto_init.py:243, in instantiate(builder, prefix, positional_args, optional_args, all_args, remove_kwargs, return_args_only, parent_builders)
#     242 try:
# --> 243     instance = builder(**positional_args, **final_optional_args)
#     244 except Exception as e:
#
# File ~/anaconda3/envs/spingnn/lib/python3.10/site-packages/allegro/nn/_etn_opt.py:150, in ETN_Module_opt.__init__(self, d, N_rank_ett, irreps_in, out_field)
#     149 # third order free parameters
# --> 150 self.cores3 = [torch.nn.Parameter(torch.Tensor(N_rank_ett[r], self.Nc, N_rank_ett[r+1], num_paths)) for r in range(d - 2)]
#     152 self.reset_parameters()
#
# File ~/anaconda3/envs/spingnn/lib/python3.10/site-packages/allegro/nn/_etn_opt.py:150, in <listcomp>(.0)
#     149 # third order free parameters
# --> 150 self.cores3 = [torch.nn.Parameter(torch.Tensor(N_rank_ett[r], self.Nc, N_rank_ett[r+1], num_paths)) for r in range(d - 2)]
#     152 self.reset_parameters()
#
# IndexError: list index out of range
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[5], line 27
#      22 config['N_rank_ett'] = [2] # ranks of tensor train
#      26 # = Build model =
# ---> 27 final_model = model_from_config(
#      28     config=config, initialize=True, dataset=trainer.dataset_train
#      29 )
#
# File ~/anaconda3/envs/spingnn/lib/python3.10/site-packages/nequip/model/_build.py:133, in model_from_config(config, initialize, dataset, deploy)
#     129     if model is not None:
#     130         raise RuntimeError(
#     131             f"All model_builders after the first one that returns a model must take the model as an argument; {builder.__name__} doesn't"
#     132         )
# --> 133 model = builder(**params)
#     134 if model is not None and not isinstance(model, GraphModuleMixin):
#     135     raise TypeError(
#     136         f"Builder {builder.__name__} didn't return a GraphModuleMixin, got {type(model)} instead"
#     137     )
#
# File ~/anaconda3/envs/spingnn/lib/python3.10/site-packages/allegro/model/_ETN_opt.py:202, in ETN_opt(config, initialize, dataset)
#     122 """
#     123 # The HEGNN allegro model:
#     124 "allegro_MSENN": (
#    (...)
#     199 ),
#     200 """
#     201 #print(config["edge_eng"])
# --> 202 model = SequentialGraphNetwork.from_parameters(shared_params=config, layers=layers)
#     204 return model
#
# File ~/anaconda3/envs/spingnn/lib/python3.10/site-packages/nequip/nn/_graph_mixin.py:193, in SequentialGraphNetwork.from_parameters(cls, shared_params, layers, irreps_in)
#     188 if not callable(builder):
#     189     raise TypeError(
#     190         f"The builder has to be a class or a function. got {type(builder)}"
#     191     )
# --> 193 instance, _ = instantiate(
#     194     builder=builder,
#     195     prefix=name,
#     196     positional_args=(
#     197         dict(
#     198             irreps_in=(
#     199                 built_modules[-1].irreps_out
#     200                 if len(built_modules) > 0
#     201                 else irreps_in
#     202             )
#     203         )
#     204     ),
#     205     optional_args=params,
#     206     all_args=shared_params,
#     207 )
#     209 if not isinstance(instance, GraphModuleMixin):
#     210     raise TypeError(
#     211         f"Builder `{builder}` for layer with name `{name}` did not return a GraphModuleMixin, instead got a {type(instance).__name__}"
#     212     )
#
# File ~/anaconda3/envs/spingnn/lib/python3.10/site-packages/nequip/utils/auto_init.py:245, in instantiate(builder, prefix, positional_args, optional_args, all_args, remove_kwargs, return_args_only, parent_builders)
#     243     instance = builder(**positional_args, **final_optional_args)
#     244 except Exception as e:
# --> 245     raise RuntimeError(
#     246         f"Failed to build object with prefix `{prefix}` using builder `{builder.__name__}`"
#     247     ) from e
#     249 return instance, final_optional_args
#
# RuntimeError: Failed to build object with prefix `etn` using builder `ETN_Module_opt`

# %%
import torch
from torch.nn.functional import one_hot
from nequip.data import AtomicData, AtomicDataDict
from torch.nn.functional import one_hot
from e3nn.nn import FullyConnectedNet
from allegro import with_edge_spin_length
from allegro import _keys
from torch import nn
import math

trainer.model = final_model

# Test configuration stores as dict of parameters
data0 = AtomicData.to_AtomicDataDict(dataset[0])

# %%
import torch
from torch.nn.functional import one_hot
from nequip.data import AtomicData, AtomicDataDict
from torch.nn.functional import one_hot
from e3nn.nn import FullyConnectedNet
    
from torch import nn
import math

# forward pass
data_new = final_model(data0)

# %% [markdown]
# ### Main module

# %% [markdown]
# I'll skip the implementation of feature vector F because it heavily relies on nequip code for neighbor lists operations.
# If you want you can look into the following files or ask me to add it to the notebook.
#
# Otherwise look into this file
#
# allegro/modules/ETN.py
#
# and corresponding layers

# %%
from typing import Optional, List
import math
import functools

import torch
from torch import nn

from e3nn import o3
from e3nn.util.jit import compile_mode

from nequip.data import AtomicDataDict # dict of base keys
from nequip.nn import GraphModuleMixin # base class for GNN (stores irreps in and out)

from allegro import _keys # just dict of additional keys

from allegro.nn._strided import Contracter_ETN
from e3nn.o3 import wigner_3j



# Triangular ineguality for path existance
def tri_ineq(l1, l2, l3):
    return max([l1, l2, l3]) <= min([l1 + l2, l2 + l3, l1 + l3])


@compile_mode("script")
class ETN_Module_opt(nn.Module, GraphModuleMixin):
    def __init__(self,
                 d: int,
                 N_rank_ett: List[int], 
                 irreps_in=None,
                 out_field: str = AtomicDataDict.PER_ATOM_ENERGY_KEY):
        
        super().__init__()
        self.out_field = out_field
        
        
        self.d = d
        self.Nc = irreps_in[_keys.NODE_FEATURES_F][0][0]
        self.register_buffer("N_rank_ett", torch.as_tensor(N_rank_ett, dtype=torch.long))
        
        # set up irreps
        self._init_irreps(
            irreps_in=irreps_in,
            required_irreps_in=[
                _keys.NODE_FEATURES_F
            ],
            irreps_out={_keys.NODE_FEATURES_ETN: o3.Irreps(
                    [(self.Nc, ir) for _, ir in irreps_in[_keys.NODE_FEATURES_F] ]),
                        out_field: o3.Irreps([(1, (0, 1))])}
        )
        
        
        # Parameters of the network
        
        # tensors for atomic features encoding
        lmax = irreps_in[_keys.EDGE_FEATURES_F].lmax # maximum spherical harmonic
        self.lmax = lmax
        
        # Second order cores(first and last)
        self.core2_1 = torch.nn.Parameter(torch.Tensor(lmax+1, self.Nc, N_rank_ett[0]))
        self.core2_d = torch.nn.Parameter(torch.Tensor(lmax+1, N_rank_ett[-1], self.Nc))
        
        
        
        # Third order cores
        # Assume irreps does not change 
        base_in1 = o3.Irreps([el[1] for el in irreps_in[_keys.EDGE_FEATURES_F]])
        base_in2 = o3.Irreps([el[1] for el in irreps_in[_keys.EDGE_FEATURES_F]])
        base_out = o3.Irreps([el[1] for el in irreps_in[_keys.EDGE_FEATURES_F]])
        

        # Building instructions
        instructions: List[Tuple[int, int, int]] = []
        tmp_i_out: int = 0
        for i_out, (_, ir_out) in enumerate(base_out):
            for i_1, (_, ir_in1) in enumerate(base_in1):
                for i_2, (_, ir_in2) in enumerate(base_in2):
                    if ir_out in ir_in1 * ir_in2:
                        instructions.append((i_1, i_2, i_out))
        
                        tmp_i_out += 1

        self.instructions = instructions
        
        # building large w3j
        w3j_values = []
        w3j_index = []
        for i_in1, i_in2, i_out in instructions:
            mul_ir_in1 = base_in1[i_in1]
            mul_ir_in2 = base_in2[i_in2]
            mul_ir_out = base_out[i_out]
    
            assert mul_ir_in1.ir.p * mul_ir_in2.ir.p == mul_ir_out.ir.p
            assert (
                tri_ineq(mul_ir_in1.ir.l, mul_ir_in2.ir.l, mul_ir_out.ir.l)
            )
    
            if mul_ir_in1.dim == 0 or mul_ir_in2.dim == 0 or mul_ir_out.dim == 0:
                raise ValueError
    
            this_w3j = o3.wigner_3j(mul_ir_in1.ir.l, mul_ir_in2.ir.l, mul_ir_out.ir.l)
            this_w3j_index = this_w3j.nonzero()
            w3j_values.append(
                this_w3j[this_w3j_index[:, 0], this_w3j_index[:, 1], this_w3j_index[:, 2]]
            )
    
            
            this_w3j_index[:, 0] += base_in1[: i_in1].dim
            this_w3j_index[:, 1] += base_in2[: i_in2].dim
            this_w3j_index[:, 2] += base_out[: i_out].dim
            # Now need to flatten the index to be for [pk][ij]
            w3j_index.append(
                torch.cat(
                    (   this_w3j_index[:, 2].unsqueeze(-1),
                        this_w3j_index[:, 0].unsqueeze(-1) * base_in2.dim
                        + this_w3j_index[:, 1].unsqueeze(-1),
                    ),
                    dim=1,
                )
            )
    
        num_paths: int = len(instructions)
    
        w3j = torch.sparse_coo_tensor(
            indices=torch.cat(w3j_index, dim=0).t(),
            values=torch.cat(w3j_values, dim=0),
            size=(
                num_paths * base_out.dim,
                base_in1.dim * base_in2.dim,
            ),
        ).coalesce()
        
        # in dense, must shape it for einsum:
        kij_shape = (
            base_out.dim,
            base_in1.dim,
            base_in2.dim,
        )
        
        # save to buffer in sparce mode + shape
        self.register_buffer("w3j", w3j)
        self.w3j_shape = (num_paths, ) + kij_shape
        
        # third order free parameters
        self.cores3 = [torch.nn.Parameter(torch.Tensor(N_rank_ett[r], self.Nc, N_rank_ett[r+1], num_paths)) for r in range(d - 2)] 
        
        self.reset_parameters()

        # Register layers
        self.tps = [Contracter_ETN(base_in1, 
                                   N_rank_ett[r], 
                                   base_in2, 
                                   self.Nc, 
                                   base_out, 
                                   N_rank_ett[r+1], 
                                   num_paths) for r in range(self.d - 2)]
        
    def forward(self, data: AtomicDataDict.Type) -> AtomicDataDict.Type:
        
        # Input features
        F = data[_keys.NODE_FEATURES_F]
        
        # Defining tensors for TorchScript
        u_out = torch.zeros((F.shape[0], F.shape[1], self.N_rank_ett[-1]), dtype=F.dtype,
            device=F.device) # temporary verctor output of etn
            
        
        data[_keys.NODE_FEATURES_ETN] = torch.zeros_like(F, dtype=F.dtype,
            device=F.device) # final feature output
        
        slices = self.irreps_in[AtomicDataDict.EDGE_ATTRS_KEY].slices() # slices over irreps

        # getting w3j in dense mode
        w3j_dense = (
            self.w3j.to_dense()
            .reshape(self.w3j_shape)
            .contiguous()
        )   
        
        # First transform using second order tensors
        for i, slice in enumerate(slices):
            u_out[:, slice, :] = torch.einsum('ij,Nmj->Nmi', self.core2_d[i], F[:, slice, :])
        
        # Series third order tensors
        for i in range(self.d - 2 - 1, -1, -1):

            # big contruction
            u_out = self.tps[i](u_out, F, w3j_dense, self.cores3[i])

        # Last transform using second order tensor
        for i, slice in enumerate(slices):
            data[_keys.NODE_FEATURES_ETN][:, slice, :] = torch.einsum('ij,Nmj->Nmi', self.core2_1[i], u_out[:, slice, :])
        
        
        # Reduction to scalar
        data[self.out_field] = ( data[_keys.NODE_FEATURES_ETN] * F ).sum(dim = (-2, -1))
        

        return data
    
    def reset_parameters(self):
        torch.nn.init.kaiming_uniform_(self.core2_1, a=math.sqrt(3))
        torch.nn.init.kaiming_uniform_(self.core2_d, a=math.sqrt(3))
        
        for core in self.cores3:
            torch.nn.init.kaiming_uniform_(core, a=math.sqrt(3))

# %% [markdown]
# ### Usage Example

# %%
ETN = ETN_Module_opt(d = config['d'],
                         N_rank_ett = config['N_rank_ett'], 
                         irreps_in = final_model.irreps_out,
                         out_field = AtomicDataDict.PER_ATOM_ENERGY_KEY)
# Out:
# /home/vladimir/anaconda3/envs/spingnn/lib/python3.10/site-packages/torch/jit/_check.py:178: UserWarning: The TorchScript type system doesn't support instance-level annotations on empty non-base types in `__init__`. Instead, either 1) use a type annotation in the class body, or 2) wrap the type in `torch.jit.Attribute`.
#   warnings.warn(
# /home/vladimir/anaconda3/envs/spingnn/lib/python3.10/site-packages/torch/jit/_check.py:178: UserWarning: The TorchScript type system doesn't support instance-level annotations on empty non-base types in `__init__`. Instead, either 1) use a type annotation in the class body, or 2) wrap the type in `torch.jit.Attribute`.
#   warnings.warn(

# %%
data_new_new = ETN(data_new)

# %% [markdown]
# ### Some equivariance testing of the final model

# %%
import torch
from torch.nn.functional import one_hot
from nequip.data import AtomicData, AtomicDataDict
from torch.nn.functional import one_hot
from e3nn.nn import FullyConnectedNet
from allegro import with_edge_spin_length
from allegro import _keys
from torch import nn
import math

data = data0


import copy

data_rot = {key: torch.clone(data0[key]) for key in data0}

irreps_sh = o3.Irreps('1x0e + 1x1o + 1x2e') #o3.Irreps.spherical_harmonics(lmax=2)
irreps_sh_r = o3.Irreps('1x1o')

alpha, beta, gamma = o3.rand_angles(100)

rot_matrix = irreps_sh.D_from_angles(alpha[0], beta[0], gamma[0])
rot_matrix_r = irreps_sh_r.D_from_angles(alpha[0], beta[0], gamma[0])


data_rot['pos'] = data_rot['pos'] @ rot_matrix_r

# %%
torch.manual_seed(32)

data_out = final_model(data)

data_out_rot = final_model(data_rot)


F = data_out['node_features_F'] # features
F_rot =data_out_rot['node_features_F'] # features from rotated positions
F_rot_rot = torch.einsum('Njn,jk->Nkn', F_rot, rot_matrix.T) # rotated features from rotated positions

assert torch.allclose(F, F_rot_rot, atol=1e-05)
print('F is equivariant')
    
    
ETN_out = data_out['node_features_ETN'] # ETN out features
ETN_out_rot =data_out_rot['node_features_ETN'] # ETN out features from rotated positions
ETN_out_rot_rot = torch.einsum('Njn,jk->Nkn', ETN_out_rot, rot_matrix.T) # rotated ETN out features from rotated positions

assert torch.allclose(ETN_out, ETN_out_rot_rot, atol=1e-05)
print('ETN forward output is equivariant')

at_en = data_out['atomic_energy'] # atomic energy
at_en_rot = data_out_rot['atomic_energy'] # atomic energy from rotated positions

assert torch.allclose(at_en, at_en_rot, atol=1e-05)
print('atomic energy is invariant')

tot_en = data_out['total_energy'] # atomic energy
tot_en_rot = data_out_rot['total_energy'] # atomic energy from rotated positions

assert torch.allclose(tot_en, tot_en_rot, atol=1e-05)
print('total energy is invariant')


f_out = data_out['forces'] # atomic forces
f_out_rot =data_out_rot['forces'] # atomic forces from rotated positions
f_out_rot_rot = f_out_rot @ rot_matrix_r.T # rotated forces from rotated positions

assert torch.allclose(f_out, f_out_rot_rot, atol=1e-05)
print('Output forces are equivariant')
# Out:
# F is equivariant
# ETN forward output is equivariant
# atomic energy is invariant
# total energy is invariant
# Output forces are equivariant

# %%
torch.manual_seed(32)

data_out = ETN(final_model(data))

data_out_rot = ETN(final_model(data_rot))


F = data_out['node_features_F'] # features
F_rot =data_out_rot['node_features_F'] # features from rotated positions
F_rot_rot = torch.einsum('Njn,jk->Nkn', F_rot, rot_matrix.T) # rotated features from rotated positions

assert torch.allclose(F, F_rot_rot, atol=1e-05)
print('F is equivariant')
    
    
ETN_out = data_out['node_features_ETN'] # ETN out features
ETN_out_rot =data_out_rot['node_features_ETN'] # ETN out features from rotated positions
ETN_out_rot_rot = torch.einsum('Njn,jk->Nkn', ETN_out_rot, rot_matrix.T) # rotated ETN out features from rotated positions

assert torch.allclose(ETN_out, ETN_out_rot_rot, atol=1e-05)
print('ETN forward output is equivariant')

at_en = data_out['atomic_energy'] # atomic energy
at_en_rot = data_out_rot['atomic_energy'] # atomic energy from rotated positions

assert torch.allclose(at_en, at_en_rot, atol=1e-05)
print('atomic energy is invariant')

tot_en = data_out['total_energy'] # atomic energy
tot_en_rot = data_out_rot['total_energy'] # atomic energy from rotated positions

assert torch.allclose(tot_en, tot_en_rot, atol=1e-05)
print('total energy is invariant')


f_out = data_out['forces'] # atomic forces
f_out_rot =data_out_rot['forces'] # atomic forces from rotated positions
f_out_rot_rot = f_out_rot @ rot_matrix_r.T # rotated forces from rotated positions

assert torch.allclose(f_out, f_out_rot_rot, atol=1e-05)
print('Output forces are equivariant')
# Out:
# F is equivariant
# ETN forward output is equivariant
# atomic energy is invariant
# total energy is invariant
# Output forces are equivariant
